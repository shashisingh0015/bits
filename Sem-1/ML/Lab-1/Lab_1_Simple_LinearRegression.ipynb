# %% [markdown]
# <a href="https://colab.research.google.com/github/shashisingh0015/bits/blob/main/Sem-1/ML/Lab-1/Lab_1_Simple_LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import all the necessary libraries
import numpy as np
import matplotlib.pyplot as mtp
import pandas as pd

# %matplotlib inline

# %%
#Import the dataset
data_set= pd.read_csv('Salary_year.csv')
#dataset that has two variables: salary (dependent variable) and experience (Independent variable).
